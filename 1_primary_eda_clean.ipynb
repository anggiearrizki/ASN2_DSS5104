# %% [markdown]
# # Primary dataset cleaning & EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 1. Merging

# %%
train_tx = pd.read_csv('data/IEEE-CIS/transaction.csv')
train_id = pd.read_csv('data/IEEE-CIS/identity.csv')

df = train_tx.merge(train_id, on='TransactionID', how='left')
df = df.copy()

# %% [markdown]
# ## 2. EDA & cleaning

# %%
print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (590540, 434)
# TransactionID       int64
# isFraud             int64
# TransactionDT       int64
# TransactionAmt    float64
# ProductCD             str
#                    ...
# id_36                 str
# id_37                 str
# id_38                 str
# DeviceType            str
# DeviceInfo            str
# Length: 434, dtype: object
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        2987000        0          86400            68.5         W  13926
# 1        2987001        0          86401            29.0         W   2755
# 2        2987002        0          86469            59.0         W   4663
# 3        2987003        0          86499            50.0         W  18132
# 4        2987004        0          86506            50.0         H   4497
#
#    card2  card3       card4  card5  ...                id_31  id_32  \
# 0    NaN  150.0    discover  142.0  ...                  NaN    NaN
# 1  404.0  150.0  mastercard  102.0  ...                  NaN    NaN
# 2  490.0  150.0        visa  166.0  ...                  NaN    NaN
# 3  567.0  150.0  mastercard  117.0  ...                  NaN    NaN
# 4  514.0  150.0  mastercard  102.0  ...  samsung browser 6.2   32.0
#
#        id_33           id_34  id_35 id_36 id_37  id_38  DeviceType  \
# 0        NaN             NaN    NaN   NaN   NaN    NaN         NaN
# 1        NaN             NaN    NaN   NaN   NaN    NaN         NaN
# 2        NaN             NaN    NaN   NaN   NaN    NaN         NaN
# 3        NaN             NaN    NaN   NaN   NaN    NaN         NaN
# 4  2220x1080  match_status:2      T     F     T      T      mobile
#
#                       DeviceInfo
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4  SAMSUNG SM-G892A Build/NRD90M
#
# [5 rows x 434 columns]

# %%
print(df['TransactionDT'].min())
print(df['TransactionDT'].max())
print((f"Time range: {(df['TransactionDT'].max() - df['TransactionDT'].min()) / 86400:.2f} days"))
# Out:
# 86400
# 15811131
# Time range: 182.00 days

# %%
duplicate_ids = df['TransactionID'].duplicated().sum()
print(f"Number of duplicate TransactionIDs: {duplicate_ids}")
# Out:
# Number of duplicate TransactionIDs: 0

# %%
sns.countplot(x='isFraud', data=df)
print(df['isFraud'].value_counts())
print(f"Fraud rate: {df['isFraud'].mean():.4f}")
# Out:
# isFraud
# 0    569877
# 1     20663
# Name: count, dtype: int64
# Fraud rate: 0.0350

# %%
df.groupby('isFraud')['TransactionAmt'].describe()

# log scale because of heavy skew
df['TransactionAmt_log'] = np.log1p(df['TransactionAmt'])
sns.boxplot(x='isFraud', y='TransactionAmt_log', data=df)
# Out:
# <Axes: xlabel='isFraud', ylabel='TransactionAmt_log'>

# %%
df['day'] = df['TransactionDT'] // 86400
fraud_by_day = df.groupby('day')['isFraud'].mean()
fraud_by_day.plot()
# Out:
# <Axes: xlabel='day'>

# %%
# distribution of C1-C14 by fraud status
for col in [f'C{i}' for i in range(1, 15)]:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x='isFraud', y=col, data=df)
    plt.title(f'{col} by Fraud Status')
    plt.show()

# %%
# check correlation between C1-C14 and isFraud
corr = df[[f'C{i}' for i in range(1, 15)] + ['isFraud']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation between C1-C14 and isFraud')
plt.show()

# %%
# % missing in C columns, show as chart
c_cols = [f'C{i}' for i in range(1, 15)]
missing_c = df[c_cols].isnull().mean() * 100
plt.figure(figsize=(8, 4))
sns.barplot(x=missing_c.index, y=missing_c.values)
plt.title('Missing Values in C1-C14')
plt.ylabel('Percentage Missing')
plt.show()

# %%
# Distribution of D1-D15 (time-based features) by fraud status
for col in [f'D{i}' for i in range(1, 16)]:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x='isFraud', y=col, data=df)
    plt.title(f'{col} by Fraud Status')
    plt.show()

# %%
# Correlation of D1-D15 with isFraud
corr_d = df[[f'D{i}' for i in range(1, 16)] + ['isFraud']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_d, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation between D1-D15 and isFraud')
plt.show()

# %%
# % missing in D columns, show as chart
d_cols = [f'D{i}' for i in range(1, 16)]
missing_d = df[d_cols].isnull().mean() * 100
plt.figure(figsize=(8, 4))
sns.barplot(x=missing_d.index, y=missing_d.values)
plt.title('Missing Values in D1-D15')
plt.ylabel('Percentage Missing')
plt.show()

# %%
# % missing in columns id_01 to id_38, show the missing % as a chart
id_cols = [f'id_{i:02d}' for i in range(1, 39)]
missing_id = df[id_cols].isnull().mean() * 100
plt.figure(figsize=(12, 6))
sns.barplot(x=missing_id.index, y=missing_id.values)
plt.title('Missing Values in id_01 to id_38')
plt.ylabel('Percentage Missing')
plt.xticks(rotation=45)
plt.show()

# %%
# drop id columns with >99% missing, drop to df_clean
cols_to_drop = missing_id[missing_id > 99].index.tolist()
print(f"Dropping columns with >99% missing: {cols_to_drop}")
df_clean = df.drop(columns=cols_to_drop)
# Out:
# Dropping columns with >99% missing: ['id_07', 'id_08', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27']

# %%
# % missing in M columns, show as chart
m_cols = [f'M{i}' for i in range(1, 10)]
missing_m = df[m_cols].isnull().mean() * 100
plt.figure(figsize=(8, 4))
sns.barplot(x=missing_m.index, y=missing_m.values)
plt.title('Missing Values in M1-M9')
plt.ylabel('Percentage Missing')
plt.show()

# %%
# % missing of V columns, show as chart
v_cols = [f'V{i}' for i in range(1, 340)]
missing_v = df[v_cols].isnull().mean() * 100
plt.figure(figsize=(12, 6))
sns.barplot(x=missing_v.index, y=missing_v.values)
plt.title('Missing Values in V1-V339')
plt.ylabel('Percentage Missing')
plt.show()

# %%
# correlation of V columns within themselves, only list those with correlation >0.9 or <-0.9
v_corr = df[v_cols].corr()
high_corr = v_corr[(v_corr > 0.9) | (v_corr < -0.9)]
high_corr_pairs = []
for i in range(len(high_corr.columns)):
    for j in range(i + 1, len(high_corr.columns)):
        if not np.isnan(high_corr.iloc[i, j]):
            high_corr_pairs.append((high_corr.columns[i], high_corr.columns[j], high_corr.iloc[i, j]))
print("Highly correlated V columns (|corr| > 0.9):")
for col1, col2, corr_value in high_corr_pairs:
    print(f"{col1} and {col2}: correlation = {corr_value:.2f}")
# Out:
# Highly correlated V columns (|corr| > 0.9):
# V4 and V5: correlation = 0.92
# V10 and V11: correlation = 0.97
# V10 and V90: correlation = 0.91
# V12 and V13: correlation = 0.93
# V15 and V16: correlation = 0.99
# V15 and V31: correlation = 0.92
# V15 and V33: correlation = 0.96
# V15 and V34: correlation = 0.92
# V15 and V50: correlation = 0.95
# V15 and V51: correlation = 0.92
# V15 and V57: correlation = 0.96
# V15 and V58: correlation = 0.93
# V15 and V71: correlation = 0.91
# V15 and V73: correlation = 0.91
# V15 and V79: correlation = 0.93
# V15 and V92: correlation = 0.91
# V15 and V94: correlation = 0.95
# V16 and V31: correlation = 0.90
# V16 and V32: correlation = 0.91
# V16 and V33: correlation = 0.94
# V16 and V34: correlation = 0.93
# V16 and V50: correlation = 0.93
# V16 and V51: correlation = 0.90
# V16 and V57: correlation = 0.94
# V16 and V58: correlation = 0.91
# V16 and V79: correlation = 0.91
# V16 and V94: correlation = 0.93
# V17 and V18: correlation = 0.99
# V17 and V21: correlation = 0.95
# V17 and V22: correlation = 0.92
# V17 and V63: correlation = 0.91
# V17 and V80: correlation = 0.90
# V17 and V84: correlation = 0.91
# V18 and V21: correlation = 0.94
# V18 and V22: correlation = 0.93
# V19 and V20: correlation = 0.91
# V21 and V22: correlation = 0.96
# V21 and V31: correlation = 0.91
# V21 and V42: correlation = 0.94
# V21 and V43: correlation = 0.90
# V21 and V50: correlation = 0.92
# V21 and V59: correlation = 0.91
# V21 and V63: correlation = 0.95
# V21 and V84: correlation = 0.96
# V21 and V92: correlation = 0.90
# V22 and V42: correlation = 0.93
# V22 and V50: correlation = 0.91
# V22 and V63: correlation = 0.92
# V22 and V64: correlation = 0.90
# V22 and V84: correlation = 0.92
# V27 and V28: correlation = 0.97
# V27 and V89: correlation = 0.94
# V28 and V68: correlation = 0.91
# V28 and V89: correlation = 0.97
# V29 and V30: correlation = 0.96
# V29 and V48: correlation = 0.92
# V29 and V69: correlation = 0.91
# V29 and V90: correlation = 0.93
# V30 and V90: correlation = 0.90
# V30 and V91: correlation = 0.92
# V31 and V32: correlation = 0.99
# V31 and V50: correlation = 0.98
# V31 and V57: correlation = 0.91
# V31 and V71: correlation = 0.96
# V31 and V72: correlation = 0.93
# V31 and V92: correlation = 0.97
# V31 and V93: correlation = 0.93
# V32 and V50: correlation = 0.96
# V32 and V71: correlation = 0.94
# V32 and V72: correlation = 0.91
# V32 and V92: correlation = 0.95
# V32 and V93: correlation = 0.91
# V33 and V34: correlation = 0.96
# V33 and V50: correlation = 0.92
# V33 and V51: correlation = 0.94
# V33 and V57: correlation = 0.92
# V33 and V73: correlation = 0.94
# V33 and V74: correlation = 0.90
# V33 and V94: correlation = 0.98
# V34 and V51: correlation = 0.90
# V34 and V94: correlation = 0.93
# V35 and V36: correlation = 0.93
# V39 and V40: correlation = 0.94
# V39 and V80: correlation = 0.90
# V41 and V88: correlation = 0.94
# V42 and V43: correlation = 0.95
# V42 and V59: correlation = 0.90
# V42 and V63: correlation = 0.95
# V42 and V64: correlation = 0.91
# V42 and V84: correlation = 0.96
# V42 and V85: correlation = 0.90
# V43 and V63: correlation = 0.91
# V43 and V64: correlation = 0.92
# V43 and V84: correlation = 0.92
# V43 and V85: correlation = 0.92
# V44 and V45: correlation = 0.91
# V48 and V49: correlation = 0.97
# V48 and V69: correlation = 0.91
# V48 and V90: correlation = 0.94
# V48 and V91: correlation = 0.91
# V49 and V90: correlation = 0.92
# V49 and V91: correlation = 0.93
# V50 and V57: correlation = 0.94
# V50 and V58: correlation = 0.91
# V50 and V71: correlation = 0.96
# V50 and V72: correlation = 0.93
# V50 and V92: correlation = 0.97
# V50 and V93: correlation = 0.93
# V50 and V94: correlation = 0.92
# V51 and V52: correlation = 0.95
# V51 and V57: correlation = 0.91
# V51 and V73: correlation = 0.94
# V51 and V74: correlation = 0.91
# V51 and V94: correlation = 0.95
# V52 and V94: correlation = 0.91
# V53 and V54: correlation = 0.92
# V57 and V58: correlation = 0.96
# V57 and V71: correlation = 0.94
# V57 and V72: correlation = 0.91
# V57 and V73: correlation = 0.94
# V57 and V74: correlation = 0.90
# V57 and V79: correlation = 0.93
# V57 and V92: correlation = 0.92
# V57 and V94: correlation = 0.94
# V58 and V71: correlation = 0.91
# V58 and V72: correlation = 0.94
# V58 and V73: correlation = 0.91
# V58 and V79: correlation = 0.95
# V58 and V93: correlation = 0.90
# V58 and V94: correlation = 0.90
# V59 and V60: correlation = 0.95
# V59 and V63: correlation = 0.93
# V59 and V80: correlation = 0.90
# V59 and V302: correlation = 0.93
# V60 and V64: correlation = 0.90
# V60 and V302: correlation = 0.91
# V60 and V304: correlation = 0.91
# V63 and V64: correlation = 0.94
# V63 and V84: correlation = 0.96
# V63 and V85: correlation = 0.90
# V64 and V84: correlation = 0.90
# V64 and V85: correlation = 0.92
# V68 and V89: correlation = 0.91
# V69 and V70: correlation = 0.96
# V69 and V90: correlation = 0.93
# V70 and V91: correlation = 0.91
# V71 and V72: correlation = 0.96
# V71 and V92: correlation = 0.96
# V71 and V93: correlation = 0.92
# V72 and V79: correlation = 0.91
# V72 and V92: correlation = 0.93
# V72 and V93: correlation = 0.95
# V73 and V74: correlation = 0.96
# V73 and V94: correlation = 0.95
# V74 and V94: correlation = 0.91
# V75 and V76: correlation = 0.92
# V79 and V93: correlation = 0.92
# V79 and V94: correlation = 0.90
# V80 and V81: correlation = 0.95
# V84 and V85: correlation = 0.94
# V90 and V91: correlation = 0.96
# V92 and V93: correlation = 0.96
# V95 and V96: correlation = 0.94
# V95 and V97: correlation = 0.94
# V95 and V101: correlation = 1.00
# V95 and V102: correlation = 0.95
# V95 and V103: correlation = 0.94
# V95 and V126: correlation = 0.98
# V95 and V127: correlation = 0.93
# V95 and V128: correlation = 0.93
# V95 and V132: correlation = 1.00
# V95 and V133: correlation = 0.95
# V95 and V134: correlation = 0.94
# V95 and V143: correlation = 0.99
# V95 and V164: correlation = 0.99
# V95 and V167: correlation = 0.99
# V95 and V168: correlation = 0.93
# V95 and V177: correlation = 0.99
# V95 and V178: correlation = 0.95
# V95 and V179: correlation = 0.94
# V95 and V202: correlation = 0.98
# V95 and V211: correlation = 0.99
# V95 and V212: correlation = 0.92
# V95 and V213: correlation = 0.94
# V95 and V279: correlation = 1.00
# V95 and V280: correlation = 0.93
# V95 and V293: correlation = 1.00
# V95 and V295: correlation = 0.93
# V95 and V306: correlation = 0.98
# V95 and V308: correlation = 0.92
# V95 and V316: correlation = 0.99
# V95 and V317: correlation = 0.90
# V95 and V318: correlation = 0.93
# V95 and V322: correlation = 1.00
# V95 and V323: correlation = 0.94
# V95 and V324: correlation = 0.94
# V95 and V331: correlation = 0.99
# V95 and V332: correlation = 0.94
# V95 and V333: correlation = 0.93
# V96 and V97: correlation = 0.99
# V96 and V101: correlation = 0.94
# V96 and V102: correlation = 1.00
# V96 and V103: correlation = 0.99
# V96 and V105: correlation = 0.93
# V96 and V126: correlation = 0.93
# V96 and V127: correlation = 0.99
# V96 and V128: correlation = 0.98
# V96 and V132: correlation = 0.94
# V96 and V133: correlation = 0.99
# V96 and V134: correlation = 0.99
# V96 and V143: correlation = 0.93
# V96 and V164: correlation = 0.94
# V96 and V167: correlation = 0.94
# V96 and V168: correlation = 0.98
# V96 and V177: correlation = 0.94
# V96 and V178: correlation = 0.99
# V96 and V179: correlation = 0.99
# V96 and V202: correlation = 0.93
# V96 and V204: correlation = 0.94
# V96 and V211: correlation = 0.94
# V96 and V212: correlation = 0.96
# V96 and V213: correlation = 0.98
# V96 and V279: correlation = 0.94
# V96 and V280: correlation = 0.98
# V96 and V293: correlation = 0.94
# V96 and V294: correlation = 0.91
# V96 and V295: correlation = 0.98
# V96 and V298: correlation = 0.91
# V96 and V306: correlation = 0.92
# V96 and V307: correlation = 0.95
# V96 and V308: correlation = 0.97
# V96 and V316: correlation = 0.93
# V96 and V317: correlation = 0.95
# V96 and V318: correlation = 0.98
# V96 and V322: correlation = 0.94
# V96 and V323: correlation = 1.00
# V96 and V324: correlation = 0.99
# V96 and V329: correlation = 0.95
# V96 and V331: correlation = 0.93
# V96 and V332: correlation = 0.99
# V96 and V333: correlation = 0.99
# V97 and V101: correlation = 0.93
# V97 and V102: correlation = 0.99
# V97 and V103: correlation = 1.00
# V97 and V105: correlation = 0.94
# V97 and V126: correlation = 0.92
# V97 and V127: correlation = 0.98
# V97 and V128: correlation = 0.99
# V97 and V132: correlation = 0.93
# V97 and V133: correlation = 0.98
# V97 and V134: correlation = 0.99
# V97 and V143: correlation = 0.92
# V97 and V164: correlation = 0.92
# V97 and V167: correlation = 0.93
# V97 and V168: correlation = 0.98
# V97 and V177: correlation = 0.92
# V97 and V178: correlation = 0.97
# V97 and V179: correlation = 0.99
# V97 and V202: correlation = 0.92
# V97 and V204: correlation = 0.94
# V97 and V211: correlation = 0.92
# V97 and V212: correlation = 0.95
# V97 and V213: correlation = 0.98
# V97 and V233: correlation = 0.90
# V97 and V279: correlation = 0.93
# V97 and V280: correlation = 0.99
# V97 and V293: correlation = 0.93
# V97 and V295: correlation = 0.99
# V97 and V298: correlation = 0.92
# V97 and V306: correlation = 0.92
# V97 and V307: correlation = 0.94
# V97 and V308: correlation = 0.98
# V97 and V316: correlation = 0.93
# V97 and V317: correlation = 0.94
# V97 and V318: correlation = 0.99
# V97 and V322: correlation = 0.94
# V97 and V323: correlation = 0.99
# V97 and V324: correlation = 1.00
# V97 and V329: correlation = 0.96
# V97 and V330: correlation = 0.90
# V97 and V331: correlation = 0.92
# V97 and V332: correlation = 0.99
# V97 and V333: correlation = 0.99
# V98 and V325: correlation = 0.95
# V99 and V326: correlation = 0.99
# V99 and V327: correlation = 0.93
# V100 and V326: correlation = 0.93
# V100 and V327: correlation = 0.99
# V101 and V102: correlation = 0.95
# V101 and V103: correlation = 0.94
# V101 and V126: correlation = 0.98
# V101 and V127: correlation = 0.93
# V101 and V128: correlation = 0.92
# V101 and V132: correlation = 1.00
# V101 and V133: correlation = 0.94
# V101 and V134: correlation = 0.94
# V101 and V143: correlation = 0.99
# V101 and V164: correlation = 0.99
# V101 and V167: correlation = 0.99
# V101 and V168: correlation = 0.93
# V101 and V177: correlation = 0.99
# V101 and V178: correlation = 0.94
# V101 and V179: correlation = 0.94
# V101 and V202: correlation = 0.98
# V101 and V211: correlation = 0.99
# V101 and V212: correlation = 0.92
# V101 and V213: correlation = 0.94
# V101 and V279: correlation = 1.00
# V101 and V280: correlation = 0.92
# V101 and V293: correlation = 1.00
# V101 and V295: correlation = 0.93
# V101 and V306: correlation = 0.98
# V101 and V308: correlation = 0.92
# V101 and V316: correlation = 0.99
# V101 and V317: correlation = 0.90
# V101 and V318: correlation = 0.93
# V101 and V322: correlation = 1.00
# V101 and V323: correlation = 0.94
# V101 and V324: correlation = 0.93
# V101 and V331: correlation = 0.99
# V101 and V332: correlation = 0.94
# V101 and V333: correlation = 0.93
# V102 and V103: correlation = 0.99
# V102 and V105: correlation = 0.92
# V102 and V126: correlation = 0.93
# V102 and V127: correlation = 0.99
# V102 and V128: correlation = 0.98
# V102 and V132: correlation = 0.94
# V102 and V133: correlation = 1.00
# V102 and V134: correlation = 0.99
# V102 and V143: correlation = 0.94
# V102 and V164: correlation = 0.94
# V102 and V167: correlation = 0.94
# V102 and V168: correlation = 0.98
# V102 and V177: correlation = 0.94
# V102 and V178: correlation = 0.99
# V102 and V179: correlation = 0.99
# V102 and V202: correlation = 0.94
# V102 and V204: correlation = 0.94
# V102 and V211: correlation = 0.94
# V102 and V212: correlation = 0.97
# V102 and V213: correlation = 0.98
# V102 and V279: correlation = 0.95
# V102 and V280: correlation = 0.98
# V102 and V293: correlation = 0.95
# V102 and V294: correlation = 0.91
# V102 and V295: correlation = 0.98
# V102 and V306: correlation = 0.93
# V102 and V307: correlation = 0.95
# V102 and V308: correlation = 0.97
# V102 and V316: correlation = 0.94
# V102 and V317: correlation = 0.95
# V102 and V318: correlation = 0.98
# V102 and V322: correlation = 0.95
# V102 and V323: correlation = 1.00
# V102 and V324: correlation = 0.99
# V102 and V329: correlation = 0.94
# V102 and V331: correlation = 0.94
# V102 and V332: correlation = 0.99
# V102 and V333: correlation = 0.98
# V103 and V105: correlation = 0.93
# V103 and V126: correlation = 0.92
# V103 and V127: correlation = 0.98
# V103 and V128: correlation = 0.99
# V103 and V132: correlation = 0.93
# V103 and V133: correlation = 0.99
# V103 and V134: correlation = 1.00
# V103 and V143: correlation = 0.93
# V103 and V164: correlation = 0.93
# V103 and V167: correlation = 0.93
# V103 and V168: correlation = 0.98
# V103 and V177: correlation = 0.93
# V103 and V178: correlation = 0.98
# V103 and V179: correlation = 0.99
# V103 and V202: correlation = 0.92
# V103 and V204: correlation = 0.94
# V103 and V211: correlation = 0.93
# V103 and V212: correlation = 0.95
# V103 and V213: correlation = 0.98
# V103 and V279: correlation = 0.94
# V103 and V280: correlation = 0.99
# V103 and V293: correlation = 0.94
# V103 and V294: correlation = 0.90
# V103 and V295: correlation = 0.99
# V103 and V298: correlation = 0.91
# V103 and V306: correlation = 0.92
# V103 and V307: correlation = 0.94
# V103 and V308: correlation = 0.98
# V103 and V316: correlation = 0.93
# V103 and V317: correlation = 0.94
# V103 and V318: correlation = 0.99
# V103 and V322: correlation = 0.94
# V103 and V323: correlation = 0.99
# V103 and V324: correlation = 1.00
# V103 and V329: correlation = 0.95
# V103 and V331: correlation = 0.93
# V103 and V332: correlation = 0.99
# V103 and V333: correlation = 0.99
# V104 and V106: correlation = 0.90
# V104 and V297: correlation = 0.92
# V104 and V328: correlation = 0.99
# V104 and V330: correlation = 0.94
# V105 and V106: correlation = 0.96
# V105 and V127: correlation = 0.92
# V105 and V128: correlation = 0.93
# V105 and V133: correlation = 0.91
# V105 and V134: correlation = 0.93
# V105 and V168: correlation = 0.93
# V105 and V178: correlation = 0.92
# V105 and V179: correlation = 0.93
# V105 and V182: correlation = 0.91
# V105 and V213: correlation = 0.92
# V105 and V280: correlation = 0.93
# V105 and V295: correlation = 0.92
# V105 and V296: correlation = 0.96
# V105 and V298: correlation = 0.98
# V105 and V299: correlation = 0.95
# V105 and V308: correlation = 0.92
# V105 and V318: correlation = 0.92
# V105 and V323: correlation = 0.95
# V105 and V324: correlation = 0.96
# V105 and V329: correlation = 1.00
# V105 and V330: correlation = 0.97
# V105 and V332: correlation = 0.94
# V105 and V333: correlation = 0.95
# V106 and V183: correlation = 0.92
# V106 and V296: correlation = 0.92
# V106 and V298: correlation = 0.94
# V106 and V299: correlation = 0.98
# V106 and V324: correlation = 0.91
# V106 and V328: correlation = 0.92
# V106 and V329: correlation = 0.97
# V106 and V330: correlation = 1.00
# V111 and V113: correlation = 0.92
# V126 and V127: correlation = 0.94
# V126 and V128: correlation = 0.94
# V126 and V132: correlation = 0.99
# V126 and V133: correlation = 0.94
# V126 and V134: correlation = 0.93
# V126 and V143: correlation = 0.98
# V126 and V164: correlation = 0.98
# V126 and V167: correlation = 0.99
# V126 and V168: correlation = 0.93
# V126 and V177: correlation = 0.99
# V126 and V178: correlation = 0.94
# V126 and V179: correlation = 0.94
# V126 and V202: correlation = 0.99
# V126 and V204: correlation = 0.90
# V126 and V211: correlation = 0.99
# V126 and V212: correlation = 0.92
# V126 and V213: correlation = 0.94
# V126 and V279: correlation = 0.98
# V126 and V280: correlation = 0.91
# V126 and V293: correlation = 0.98
# V126 and V295: correlation = 0.91
# V126 and V306: correlation = 0.99
# V126 and V308: correlation = 0.93
# V126 and V316: correlation = 0.99
# V126 and V318: correlation = 0.93
# V126 and V322: correlation = 0.99
# V126 and V323: correlation = 0.93
# V126 and V324: correlation = 0.92
# V126 and V331: correlation = 1.00
# V126 and V332: correlation = 0.94
# V126 and V333: correlation = 0.94
# V127 and V128: correlation = 0.99
# V127 and V132: correlation = 0.94
# V127 and V133: correlation = 0.99
# V127 and V134: correlation = 0.99
# V127 and V143: correlation = 0.93
# V127 and V164: correlation = 0.94
# V127 and V167: correlation = 0.94
# V127 and V168: correlation = 0.97
# V127 and V177: correlation = 0.94
# V127 and V178: correlation = 0.99
# V127 and V179: correlation = 0.98
# V127 and V202: correlation = 0.94
# V127 and V204: correlation = 0.94
# V127 and V211: correlation = 0.94
# V127 and V212: correlation = 0.96
# V127 and V213: correlation = 0.98
# V127 and V279: correlation = 0.93
# V127 and V280: correlation = 0.97
# V127 and V293: correlation = 0.93
# V127 and V295: correlation = 0.97
# V127 and V306: correlation = 0.93
# V127 and V307: correlation = 0.96
# V127 and V308: correlation = 0.98
# V127 and V316: correlation = 0.93
# V127 and V317: correlation = 0.95
# V127 and V318: correlation = 0.98
# V127 and V322: correlation = 0.94
# V127 and V323: correlation = 0.99
# V127 and V324: correlation = 0.99
# V127 and V329: correlation = 0.94
# V127 and V331: correlation = 0.94
# V127 and V332: correlation = 1.00
# V127 and V333: correlation = 0.99
# V128 and V132: correlation = 0.93
# V128 and V133: correlation = 0.98
# V128 and V134: correlation = 0.99
# V128 and V143: correlation = 0.92
# V128 and V164: correlation = 0.92
# V128 and V167: correlation = 0.93
# V128 and V168: correlation = 0.98
# V128 and V177: correlation = 0.92
# V128 and V178: correlation = 0.97
# V128 and V179: correlation = 0.98
# V128 and V202: correlation = 0.93
# V128 and V204: correlation = 0.95
# V128 and V211: correlation = 0.93
# V128 and V212: correlation = 0.95
# V128 and V213: correlation = 0.98
# V128 and V279: correlation = 0.93
# V128 and V280: correlation = 0.98
# V128 and V293: correlation = 0.92
# V128 and V295: correlation = 0.97
# V128 and V298: correlation = 0.91
# V128 and V306: correlation = 0.93
# V128 and V307: correlation = 0.95
# V128 and V308: correlation = 0.99
# V128 and V316: correlation = 0.93
# V128 and V317: correlation = 0.94
# V128 and V318: correlation = 0.98
# V128 and V322: correlation = 0.93
# V128 and V323: correlation = 0.99
# V128 and V324: correlation = 0.99
# V128 and V329: correlation = 0.95
# V128 and V331: correlation = 0.94
# V128 and V332: correlation = 0.99
# V128 and V333: correlation = 1.00
# V129 and V206: correlation = 0.96
# V129 and V266: correlation = 0.96
# V129 and V269: correlation = 0.96
# V129 and V309: correlation = 0.92
# V129 and V334: correlation = 0.95
# V131 and V266: correlation = 0.91
# V131 and V269: correlation = 0.91
# V131 and V336: correlation = 0.92
# V132 and V133: correlation = 0.95
# V132 and V134: correlation = 0.94
# V132 and V143: correlation = 0.99
# V132 and V164: correlation = 0.99
# V132 and V167: correlation = 0.99
# V132 and V168: correlation = 0.93
# V132 and V177: correlation = 0.99
# V132 and V178: correlation = 0.95
# V132 and V179: correlation = 0.94
# V132 and V202: correlation = 0.98
# V132 and V211: correlation = 0.99
# V132 and V212: correlation = 0.93
# V132 and V213: correlation = 0.94
# V132 and V279: correlation = 0.99
# V132 and V280: correlation = 0.92
# V132 and V293: correlation = 0.99
# V132 and V295: correlation = 0.92
# V132 and V306: correlation = 0.98
# V132 and V308: correlation = 0.92
# V132 and V316: correlation = 1.00
# V132 and V317: correlation = 0.90
# V132 and V318: correlation = 0.93
# V132 and V322: correlation = 1.00
# V132 and V323: correlation = 0.94
# V132 and V324: correlation = 0.93
# V132 and V331: correlation = 0.99
# V132 and V332: correlation = 0.94
# V132 and V333: correlation = 0.93
# V133 and V134: correlation = 0.99
# V133 and V143: correlation = 0.94
# V133 and V164: correlation = 0.94
# V133 and V167: correlation = 0.95
# V133 and V168: correlation = 0.97
# V133 and V177: correlation = 0.95
# V133 and V178: correlation = 0.99
# V133 and V179: correlation = 0.98
# V133 and V202: correlation = 0.94
# V133 and V204: correlation = 0.94
# V133 and V211: correlation = 0.95
# V133 and V212: correlation = 0.97
# V133 and V213: correlation = 0.98
# V133 and V279: correlation = 0.95
# V133 and V280: correlation = 0.97
# V133 and V293: correlation = 0.94
# V133 and V294: correlation = 0.91
# V133 and V295: correlation = 0.97
# V133 and V306: correlation = 0.94
# V133 and V307: correlation = 0.95
# V133 and V308: correlation = 0.97
# V133 and V316: correlation = 0.95
# V133 and V317: correlation = 0.95
# V133 and V318: correlation = 0.98
# V133 and V322: correlation = 0.95
# V133 and V323: correlation = 1.00
# V133 and V324: correlation = 0.99
# V133 and V329: correlation = 0.93
# V133 and V331: correlation = 0.94
# V133 and V332: correlation = 1.00
# V133 and V333: correlation = 0.98
# V134 and V143: correlation = 0.93
# V134 and V164: correlation = 0.94
# V134 and V167: correlation = 0.94
# V134 and V168: correlation = 0.98
# V134 and V177: correlation = 0.93
# V134 and V178: correlation = 0.98
# V134 and V179: correlation = 0.99
# V134 and V202: correlation = 0.93
# V134 and V204: correlation = 0.94
# V134 and V211: correlation = 0.93
# V134 and V212: correlation = 0.96
# V134 and V213: correlation = 0.98
# V134 and V279: correlation = 0.94
# V134 and V280: correlation = 0.98
# V134 and V293: correlation = 0.94
# V134 and V295: correlation = 0.98
# V134 and V298: correlation = 0.90
# V134 and V306: correlation = 0.93
# V134 and V307: correlation = 0.94
# V134 and V308: correlation = 0.98
# V134 and V316: correlation = 0.94
# V134 and V317: correlation = 0.95
# V134 and V318: correlation = 0.99
# V134 and V322: correlation = 0.94
# V134 and V323: correlation = 0.99
# V134 and V324: correlation = 1.00
# V134 and V329: correlation = 0.95
# V134 and V331: correlation = 0.94
# V134 and V332: correlation = 0.99
# V134 and V333: correlation = 0.99
# V135 and V137: correlation = 0.91
# V136 and V137: correlation = 0.93
# V139 and V140: correlation = 0.95
# V143 and V164: correlation = 1.00
# V143 and V167: correlation = 0.98
# V143 and V168: correlation = 0.92
# V143 and V177: correlation = 0.98
# V143 and V178: correlation = 0.93
# V143 and V179: correlation = 0.93
# V143 and V202: correlation = 0.97
# V143 and V211: correlation = 0.98
# V143 and V212: correlation = 0.91
# V143 and V213: correlation = 0.93
# V143 and V279: correlation = 0.99
# V143 and V280: correlation = 0.92
# V143 and V293: correlation = 0.99
# V143 and V294: correlation = 0.94
# V143 and V295: correlation = 0.93
# V143 and V306: correlation = 0.98
# V143 and V307: correlation = 0.93
# V143 and V308: correlation = 0.92
# V143 and V316: correlation = 0.99
# V143 and V317: correlation = 0.94
# V143 and V318: correlation = 0.93
# V143 and V322: correlation = 0.99
# V143 and V323: correlation = 0.93
# V143 and V324: correlation = 0.92
# V143 and V331: correlation = 0.98
# V143 and V332: correlation = 0.93
# V143 and V333: correlation = 0.92
# V144 and V145: correlation = 0.95
# V144 and V150: correlation = 0.96
# V144 and V151: correlation = 0.92
# V144 and V159: correlation = 0.94
# V145 and V150: correlation = 0.98
# V145 and V151: correlation = 0.94
# V145 and V159: correlation = 0.92
# V145 and V160: correlation = 0.96
# V146 and V147: correlation = 0.93
# V148 and V149: correlation = 0.95
# V148 and V153: correlation = 0.95
# V148 and V154: correlation = 0.94
# V148 and V155: correlation = 0.98
# V148 and V156: correlation = 0.93
# V148 and V157: correlation = 0.92
# V149 and V153: correlation = 0.90
# V149 and V154: correlation = 0.92
# V149 and V155: correlation = 0.93
# V149 and V156: correlation = 0.98
# V149 and V158: correlation = 0.92
# V150 and V151: correlation = 0.97
# V150 and V159: correlation = 0.97
# V150 and V160: correlation = 0.94
# V151 and V152: correlation = 0.94
# V151 and V159: correlation = 0.96
# V151 and V160: correlation = 0.91
# V153 and V154: correlation = 0.99
# V153 and V155: correlation = 0.96
# V153 and V156: correlation = 0.91
# V154 and V155: correlation = 0.95
# V154 and V156: correlation = 0.93
# V155 and V156: correlation = 0.95
# V155 and V157: correlation = 0.92
# V156 and V158: correlation = 0.93
# V157 and V158: correlation = 0.95
# V161 and V163: correlation = 0.95
# V162 and V163: correlation = 0.95
# V164 and V167: correlation = 0.99
# V164 and V168: correlation = 0.92
# V164 and V177: correlation = 0.99
# V164 and V178: correlation = 0.94
# V164 and V179: correlation = 0.93
# V164 and V202: correlation = 0.98
# V164 and V211: correlation = 0.99
# V164 and V212: correlation = 0.92
# V164 and V213: correlation = 0.93
# V164 and V279: correlation = 0.99
# V164 and V280: correlation = 0.93
# V164 and V293: correlation = 0.99
# V164 and V294: correlation = 0.94
# V164 and V295: correlation = 0.93
# V164 and V306: correlation = 0.98
# V164 and V307: correlation = 0.94
# V164 and V308: correlation = 0.92
# V164 and V316: correlation = 0.99
# V164 and V317: correlation = 0.94
# V164 and V318: correlation = 0.94
# V164 and V322: correlation = 0.99
# V164 and V323: correlation = 0.94
# V164 and V324: correlation = 0.92
# V164 and V331: correlation = 0.98
# V164 and V332: correlation = 0.94
# V164 and V333: correlation = 0.92
# V167 and V168: correlation = 0.94
# V167 and V177: correlation = 1.00
# V167 and V178: correlation = 0.95
# V167 and V179: correlation = 0.95
# V167 and V202: correlation = 0.99
# V167 and V204: correlation = 0.91
# V167 and V211: correlation = 1.00
# V167 and V212: correlation = 0.94
# V167 and V213: correlation = 0.95
# V167 and V217: correlation = 0.96
# V167 and V218: correlation = 0.92
# V167 and V219: correlation = 0.95
# V167 and V231: correlation = 0.96
# V167 and V232: correlation = 0.95
# V167 and V233: correlation = 0.95
# V167 and V273: correlation = 0.93
# V167 and V275: correlation = 0.91
# V167 and V279: correlation = 0.99
# V167 and V280: correlation = 0.93
# V167 and V293: correlation = 0.99
# V167 and V294: correlation = 0.93
# V167 and V295: correlation = 0.93
# V167 and V306: correlation = 0.98
# V167 and V307: correlation = 0.93
# V167 and V308: correlation = 0.93
# V167 and V316: correlation = 0.99
# V167 and V317: correlation = 0.94
# V167 and V318: correlation = 0.94
# V167 and V322: correlation = 0.99
# V167 and V323: correlation = 0.94
# V167 and V324: correlation = 0.93
# V167 and V331: correlation = 0.99
# V167 and V332: correlation = 0.94
# V167 and V333: correlation = 0.93
# V168 and V177: correlation = 0.93
# V168 and V178: correlation = 0.99
# V168 and V179: correlation = 1.00
# V168 and V182: correlation = 0.91
# V168 and V202: correlation = 0.93
# V168 and V203: correlation = 0.92
# V168 and V204: correlation = 0.98
# V168 and V211: correlation = 0.93
# V168 and V212: correlation = 0.98
# V168 and V213: correlation = 1.00
# V168 and V217: correlation = 0.95
# V168 and V218: correlation = 0.94
# V168 and V219: correlation = 0.96
# V168 and V231: correlation = 0.95
# V168 and V232: correlation = 0.95
# V168 and V233: correlation = 0.96
# V168 and V273: correlation = 0.91
# V168 and V275: correlation = 0.91
# V168 and V279: correlation = 0.93
# V168 and V280: correlation = 0.98
# V168 and V293: correlation = 0.93
# V168 and V294: correlation = 0.96
# V168 and V295: correlation = 0.98
# V168 and V296: correlation = 0.92
# V168 and V298: correlation = 0.93
# V168 and V306: correlation = 0.92
# V168 and V307: correlation = 0.97
# V168 and V308: correlation = 0.97
# V168 and V316: correlation = 0.93
# V168 and V317: correlation = 0.97
# V168 and V318: correlation = 0.98
# V168 and V322: correlation = 0.93
# V168 and V323: correlation = 0.98
# V168 and V324: correlation = 0.98
# V168 and V329: correlation = 0.93
# V168 and V331: correlation = 0.93
# V168 and V332: correlation = 0.97
# V168 and V333: correlation = 0.98
# V176 and V190: correlation = 0.91
# V177 and V178: correlation = 0.95
# V177 and V179: correlation = 0.95
# V177 and V202: correlation = 0.99
# V177 and V204: correlation = 0.90
# V177 and V211: correlation = 1.00
# V177 and V212: correlation = 0.93
# V177 and V213: correlation = 0.94
# V177 and V217: correlation = 0.96
# V177 and V218: correlation = 0.92
# V177 and V219: correlation = 0.95
# V177 and V231: correlation = 0.96
# V177 and V232: correlation = 0.95
# V177 and V233: correlation = 0.96
# V177 and V273: correlation = 0.93
# V177 and V275: correlation = 0.91
# V177 and V279: correlation = 0.99
# V177 and V280: correlation = 0.92
# V177 and V293: correlation = 0.99
# V177 and V294: correlation = 0.93
# V177 and V295: correlation = 0.93
# V177 and V306: correlation = 0.98
# V177 and V307: correlation = 0.93
# V177 and V308: correlation = 0.92
# V177 and V316: correlation = 0.99
# V177 and V317: correlation = 0.94
# V177 and V318: correlation = 0.93
# V177 and V322: correlation = 0.99
# V177 and V323: correlation = 0.94
# V177 and V324: correlation = 0.92
# V177 and V331: correlation = 0.99
# V177 and V332: correlation = 0.94
# V177 and V333: correlation = 0.92
# V178 and V179: correlation = 0.99
# V178 and V202: correlation = 0.95
# V178 and V203: correlation = 0.91
# V178 and V204: correlation = 0.96
# V178 and V211: correlation = 0.95
# V178 and V212: correlation = 0.99
# V178 and V213: correlation = 0.99
# V178 and V217: correlation = 0.95
# V178 and V218: correlation = 0.93
# V178 and V219: correlation = 0.95
# V178 and V231: correlation = 0.95
# V178 and V232: correlation = 0.95
# V178 and V233: correlation = 0.96
# V178 and V273: correlation = 0.91
# V178 and V275: correlation = 0.91
# V178 and V279: correlation = 0.95
# V178 and V280: correlation = 0.97
# V178 and V293: correlation = 0.94
# V178 and V294: correlation = 0.98
# V178 and V295: correlation = 0.98
# V178 and V296: correlation = 0.91
# V178 and V298: correlation = 0.91
# V178 and V306: correlation = 0.94
# V178 and V307: correlation = 0.98
# V178 and V308: correlation = 0.97
# V178 and V316: correlation = 0.95
# V178 and V317: correlation = 0.98
# V178 and V318: correlation = 0.98
# V178 and V322: correlation = 0.95
# V178 and V323: correlation = 0.99
# V178 and V324: correlation = 0.98
# V178 and V329: correlation = 0.92
# V178 and V331: correlation = 0.94
# V178 and V332: correlation = 0.99
# V178 and V333: correlation = 0.97
# V179 and V202: correlation = 0.94
# V179 and V204: correlation = 0.96
# V179 and V211: correlation = 0.95
# V179 and V212: correlation = 0.97
# V179 and V213: correlation = 1.00
# V179 and V217: correlation = 0.95
# V179 and V218: correlation = 0.93
# V179 and V219: correlation = 0.95
# V179 and V231: correlation = 0.95
# V179 and V232: correlation = 0.96
# V179 and V233: correlation = 0.96
# V179 and V273: correlation = 0.92
# V179 and V275: correlation = 0.91
# V179 and V279: correlation = 0.94
# V179 and V280: correlation = 0.99
# V179 and V293: correlation = 0.94
# V179 and V294: correlation = 0.97
# V179 and V295: correlation = 0.99
# V179 and V296: correlation = 0.92
# V179 and V298: correlation = 0.93
# V179 and V306: correlation = 0.93
# V179 and V307: correlation = 0.98
# V179 and V308: correlation = 0.98
# V179 and V316: correlation = 0.94
# V179 and V317: correlation = 0.98
# V179 and V318: correlation = 0.99
# V179 and V322: correlation = 0.94
# V179 and V323: correlation = 0.99
# V179 and V324: correlation = 0.99
# V179 and V329: correlation = 0.93
# V179 and V331: correlation = 0.94
# V179 and V332: correlation = 0.98
# V179 and V333: correlation = 0.98
# V180 and V182: correlation = 0.99
# V180 and V183: correlation = 0.92
# V180 and V203: correlation = 0.91
# V181 and V183: correlation = 0.92
# V181 and V235: correlation = 0.95
# V181 and V328: correlation = 0.91
# V182 and V183: correlation = 0.95
# V182 and V203: correlation = 0.92
# V182 and V204: correlation = 0.91
# V182 and V212: correlation = 0.90
# V182 and V236: correlation = 0.91
# V182 and V237: correlation = 0.91
# V182 and V298: correlation = 0.90
# V182 and V329: correlation = 0.91
# V183 and V236: correlation = 0.91
# V183 and V237: correlation = 0.95
# V183 and V299: correlation = 0.91
# V183 and V330: correlation = 0.92
# V186 and V190: correlation = 0.93
# V186 and V196: correlation = 0.91
# V187 and V192: correlation = 0.96
# V187 and V193: correlation = 0.93
# V190 and V199: correlation = 0.96
# V191 and V193: correlation = 0.92
# V191 and V196: correlation = 0.97
# V192 and V193: correlation = 0.96
# V194 and V197: correlation = 0.91
# V195 and V198: correlation = 0.91
# V196 and V207: correlation = 0.91
# V200 and V201: correlation = 0.94
# V202 and V204: correlation = 0.93
# V202 and V211: correlation = 0.99
# V202 and V212: correlation = 0.94
# V202 and V213: correlation = 0.94
# V202 and V263: correlation = 0.97
# V202 and V265: correlation = 0.91
# V202 and V279: correlation = 0.98
# V202 and V280: correlation = 0.92
# V202 and V293: correlation = 0.98
# V202 and V294: correlation = 0.92
# V202 and V295: correlation = 0.92
# V202 and V306: correlation = 0.99
# V202 and V307: correlation = 0.93
# V202 and V308: correlation = 0.93
# V202 and V316: correlation = 0.98
# V202 and V317: correlation = 0.93
# V202 and V318: correlation = 0.93
# V202 and V322: correlation = 0.98
# V202 and V323: correlation = 0.93
# V202 and V324: correlation = 0.92
# V202 and V331: correlation = 0.99
# V202 and V332: correlation = 0.94
# V202 and V333: correlation = 0.93
# V203 and V204: correlation = 0.96
# V203 and V212: correlation = 0.96
# V203 and V213: correlation = 0.91
# V203 and V265: correlation = 0.92
# V204 and V211: correlation = 0.91
# V204 and V212: correlation = 0.98
# V204 and V213: correlation = 0.98
# V204 and V263: correlation = 0.92
# V204 and V265: correlation = 0.95
# V204 and V280: correlation = 0.94
# V204 and V294: correlation = 0.93
# V204 and V295: correlation = 0.94
# V204 and V306: correlation = 0.90
# V204 and V307: correlation = 0.94
# V204 and V308: correlation = 0.95
# V204 and V317: correlation = 0.93
# V204 and V318: correlation = 0.94
# V204 and V323: correlation = 0.94
# V204 and V324: correlation = 0.94
# V204 and V331: correlation = 0.90
# V204 and V332: correlation = 0.94
# V204 and V333: correlation = 0.95
# V205 and V266: correlation = 0.98
# V205 and V269: correlation = 0.98
# V206 and V266: correlation = 0.96
# V206 and V269: correlation = 0.96
# V206 and V309: correlation = 0.95
# V206 and V311: correlation = 0.97
# V206 and V334: correlation = 0.91
# V207 and V266: correlation = 0.93
# V207 and V269: correlation = 0.93
# V211 and V212: correlation = 0.94
# V211 and V213: correlation = 0.95
# V211 and V217: correlation = 0.93
# V211 and V219: correlation = 0.92
# V211 and V231: correlation = 0.93
# V211 and V232: correlation = 0.92
# V211 and V233: correlation = 0.92
# V211 and V273: correlation = 0.96
# V211 and V275: correlation = 0.94
# V211 and V279: correlation = 0.99
# V211 and V280: correlation = 0.92
# V211 and V293: correlation = 0.99
# V211 and V294: correlation = 0.93
# V211 and V295: correlation = 0.93
# V211 and V306: correlation = 0.98
# V211 and V307: correlation = 0.93
# V211 and V308: correlation = 0.92
# V211 and V316: correlation = 0.99
# V211 and V317: correlation = 0.94
# V211 and V318: correlation = 0.93
# V211 and V322: correlation = 0.99
# V211 and V323: correlation = 0.94
# V211 and V324: correlation = 0.92
# V211 and V331: correlation = 0.99
# V211 and V332: correlation = 0.94
# V211 and V333: correlation = 0.93
# V212 and V213: correlation = 0.98
# V212 and V233: correlation = 0.90
# V212 and V273: correlation = 0.92
# V212 and V274: correlation = 0.91
# V212 and V275: correlation = 0.93
# V212 and V279: correlation = 0.92
# V212 and V280: correlation = 0.95
# V212 and V293: correlation = 0.92
# V212 and V294: correlation = 0.95
# V212 and V295: correlation = 0.95
# V212 and V306: correlation = 0.92
# V212 and V307: correlation = 0.96
# V212 and V308: correlation = 0.95
# V212 and V316: correlation = 0.93
# V212 and V317: correlation = 0.96
# V212 and V318: correlation = 0.96
# V212 and V322: correlation = 0.92
# V212 and V323: correlation = 0.96
# V212 and V324: correlation = 0.95
# V212 and V331: correlation = 0.92
# V212 and V332: correlation = 0.96
# V212 and V333: correlation = 0.95
# V213 and V217: correlation = 0.91
# V213 and V219: correlation = 0.91
# V213 and V231: correlation = 0.91
# V213 and V232: correlation = 0.91
# V213 and V233: correlation = 0.92
# V213 and V273: correlation = 0.94
# V213 and V275: correlation = 0.96
# V213 and V279: correlation = 0.94
# V213 and V280: correlation = 0.98
# V213 and V293: correlation = 0.94
# V213 and V294: correlation = 0.97
# V213 and V295: correlation = 0.98
# V213 and V296: correlation = 0.91
# V213 and V298: correlation = 0.92
# V213 and V306: correlation = 0.93
# V213 and V307: correlation = 0.97
# V213 and V308: correlation = 0.98
# V213 and V316: correlation = 0.94
# V213 and V317: correlation = 0.98
# V213 and V318: correlation = 0.98
# V213 and V322: correlation = 0.94
# V213 and V323: correlation = 0.98
# V213 and V324: correlation = 0.98
# V213 and V329: correlation = 0.92
# V213 and V331: correlation = 0.94
# V213 and V332: correlation = 0.98
# V213 and V333: correlation = 0.98
# V214 and V216: correlation = 0.91
# V214 and V276: correlation = 0.99
# V214 and V278: correlation = 0.94
# V215 and V276: correlation = 0.93
# V215 and V277: correlation = 0.95
# V215 and V278: correlation = 0.97
# V216 and V276: correlation = 0.95
# V216 and V277: correlation = 0.94
# V216 and V278: correlation = 0.98
# V217 and V218: correlation = 0.93
# V217 and V219: correlation = 0.98
# V217 and V231: correlation = 1.00
# V217 and V232: correlation = 0.98
# V217 and V233: correlation = 0.99
# V217 and V273: correlation = 0.95
# V217 and V275: correlation = 0.91
# V217 and V322: correlation = 0.91
# V217 and V324: correlation = 0.91
# V218 and V219: correlation = 0.97
# V218 and V231: correlation = 0.91
# V218 and V232: correlation = 0.95
# V218 and V233: correlation = 0.93
# V218 and V236: correlation = 0.90
# V218 and V274: correlation = 0.91
# V219 and V231: correlation = 0.97
# V219 and V232: correlation = 0.99
# V219 and V233: correlation = 0.99
# V219 and V273: correlation = 0.93
# V219 and V275: correlation = 0.92
# V219 and V323: correlation = 0.90
# V219 and V324: correlation = 0.91
# V221 and V222: correlation = 0.97
# V221 and V259: correlation = 0.93
# V222 and V259: correlation = 0.90
# V224 and V225: correlation = 0.95
# V227 and V245: correlation = 0.90
# V229 and V243: correlation = 0.91
# V229 and V253: correlation = 0.90
# V231 and V232: correlation = 0.98
# V231 and V233: correlation = 0.99
# V231 and V273: correlation = 0.95
# V231 and V275: correlation = 0.91
# V231 and V322: correlation = 0.91
# V231 and V324: correlation = 0.91
# V232 and V233: correlation = 0.99
# V232 and V273: correlation = 0.94
# V232 and V275: correlation = 0.92
# V232 and V323: correlation = 0.90
# V232 and V324: correlation = 0.91
# V233 and V273: correlation = 0.94
# V233 and V275: correlation = 0.92
# V233 and V322: correlation = 0.90
# V233 and V323: correlation = 0.90
# V233 and V324: correlation = 0.91
# V234 and V236: correlation = 0.98
# V234 and V237: correlation = 0.92
# V235 and V237: correlation = 0.91
# V236 and V237: correlation = 0.96
# V237 and V330: correlation = 0.91
# V238 and V239: correlation = 0.95
# V242 and V244: correlation = 0.97
# V245 and V259: correlation = 0.94
# V246 and V257: correlation = 0.91
# V248 and V249: correlation = 0.96
# V248 and V253: correlation = 0.96
# V248 and V254: correlation = 0.95
# V249 and V254: correlation = 0.93
# V250 and V251: correlation = 0.98
# V253 and V254: correlation = 0.98
# V255 and V256: correlation = 0.98
# V263 and V265: correlation = 0.91
# V266 and V269: correlation = 1.00
# V266 and V309: correlation = 0.95
# V266 and V311: correlation = 0.93
# V266 and V312: correlation = 0.91
# V266 and V334: correlation = 0.93
# V266 and V336: correlation = 0.90
# V269 and V309: correlation = 0.95
# V269 and V311: correlation = 0.93
# V269 and V312: correlation = 0.90
# V269 and V334: correlation = 0.93
# V270 and V271: correlation = 0.92
# V270 and V272: correlation = 0.96
# V271 and V272: correlation = 0.97
# V273 and V275: correlation = 0.95
# V276 and V278: correlation = 0.95
# V277 and V278: correlation = 0.95
# V279 and V280: correlation = 0.93
# V279 and V293: correlation = 1.00
# V279 and V295: correlation = 0.93
# V279 and V306: correlation = 0.98
# V279 and V307: correlation = 0.90
# V279 and V308: correlation = 0.92
# V279 and V316: correlation = 0.99
# V279 and V317: correlation = 0.91
# V279 and V318: correlation = 0.94
# V279 and V322: correlation = 1.00
# V279 and V323: correlation = 0.94
# V279 and V324: correlation = 0.94
# V279 and V331: correlation = 0.99
# V279 and V332: correlation = 0.94
# V279 and V333: correlation = 0.93
# V280 and V293: correlation = 0.93
# V280 and V294: correlation = 0.95
# V280 and V295: correlation = 1.00
# V280 and V296: correlation = 0.90
# V280 and V298: correlation = 0.92
# V280 and V306: correlation = 0.91
# V280 and V307: correlation = 0.97
# V280 and V308: correlation = 0.98
# V280 and V316: correlation = 0.92
# V280 and V317: correlation = 0.97
# V280 and V318: correlation = 0.99
# V280 and V322: correlation = 0.94
# V280 and V323: correlation = 0.99
# V280 and V324: correlation = 1.00
# V280 and V329: correlation = 0.96
# V280 and V330: correlation = 0.90
# V280 and V331: correlation = 0.92
# V280 and V332: correlation = 0.99
# V280 and V333: correlation = 0.99
# V284 and V325: correlation = 0.92
# V285 and V326: correlation = 0.96
# V285 and V327: correlation = 0.90
# V287 and V326: correlation = 0.92
# V287 and V327: correlation = 0.97
# V291 and V292: correlation = 0.97
# V293 and V295: correlation = 0.93
# V293 and V306: correlation = 0.98
# V293 and V308: correlation = 0.92
# V293 and V316: correlation = 0.99
# V293 and V317: correlation = 0.91
# V293 and V318: correlation = 0.93
# V293 and V322: correlation = 1.00
# V293 and V323: correlation = 0.94
# V293 and V324: correlation = 0.93
# V293 and V331: correlation = 0.99
# V293 and V332: correlation = 0.94
# V293 and V333: correlation = 0.93
# V294 and V295: correlation = 0.95
# V294 and V307: correlation = 0.97
# V294 and V308: correlation = 0.92
# V294 and V317: correlation = 0.98
# V294 and V318: correlation = 0.93
# V294 and V322: correlation = 0.95
# V294 and V323: correlation = 1.00
# V294 and V324: correlation = 0.99
# V294 and V329: correlation = 0.94
# V294 and V331: correlation = 0.94
# V294 and V332: correlation = 0.99
# V294 and V333: correlation = 0.98
# V295 and V298: correlation = 0.91
# V295 and V306: correlation = 0.92
# V295 and V307: correlation = 0.97
# V295 and V308: correlation = 0.98
# V295 and V316: correlation = 0.93
# V295 and V317: correlation = 0.97
# V295 and V318: correlation = 0.99
# V295 and V322: correlation = 0.94
# V295 and V323: correlation = 0.99
# V295 and V324: correlation = 1.00
# V295 and V329: correlation = 0.95
# V295 and V331: correlation = 0.93
# V295 and V332: correlation = 0.99
# V295 and V333: correlation = 0.99
# V296 and V298: correlation = 0.99
# V296 and V299: correlation = 0.94
# V296 and V323: correlation = 0.94
# V296 and V324: correlation = 0.95
# V296 and V329: correlation = 0.99
# V296 and V330: correlation = 0.96
# V296 and V332: correlation = 0.93
# V296 and V333: correlation = 0.94
# V297 and V328: correlation = 0.97
# V297 and V330: correlation = 0.94
# V298 and V299: correlation = 0.96
# V298 and V308: correlation = 0.91
# V298 and V318: correlation = 0.90
# V298 and V323: correlation = 0.95
# V298 and V324: correlation = 0.96
# V298 and V329: correlation = 1.00
# V298 and V330: correlation = 0.96
# V298 and V332: correlation = 0.94
# V298 and V333: correlation = 0.95
# V299 and V324: correlation = 0.92
# V299 and V328: correlation = 0.92
# V299 and V329: correlation = 0.97
# V299 and V330: correlation = 0.99
# V299 and V333: correlation = 0.90
# V300 and V301: correlation = 0.93
# V302 and V304: correlation = 0.96
# V303 and V304: correlation = 0.94
# V306 and V307: correlation = 0.91
# V306 and V308: correlation = 0.94
# V306 and V316: correlation = 0.99
# V306 and V317: correlation = 0.90
# V306 and V318: correlation = 0.93
# V306 and V322: correlation = 0.99
# V306 and V323: correlation = 0.93
# V306 and V324: correlation = 0.92
# V306 and V331: correlation = 0.99
# V306 and V332: correlation = 0.94
# V306 and V333: correlation = 0.94
# V307 and V308: correlation = 0.97
# V307 and V316: correlation = 0.90
# V307 and V317: correlation = 0.99
# V307 and V318: correlation = 0.97
# V307 and V322: correlation = 0.94
# V307 and V323: correlation = 0.99
# V307 and V324: correlation = 0.98
# V307 and V329: correlation = 0.94
# V307 and V331: correlation = 0.94
# V307 and V332: correlation = 1.00
# V307 and V333: correlation = 0.99
# V308 and V316: correlation = 0.93
# V308 and V317: correlation = 0.96
# V308 and V318: correlation = 0.99
# V308 and V322: correlation = 0.93
# V308 and V323: correlation = 0.99
# V308 and V324: correlation = 0.99
# V308 and V329: correlation = 0.95
# V308 and V331: correlation = 0.94
# V308 and V332: correlation = 0.99
# V308 and V333: correlation = 1.00
# V309 and V334: correlation = 0.95
# V311 and V334: correlation = 0.92
# V312 and V336: correlation = 0.94
# V313 and V315: correlation = 0.92
# V316 and V317: correlation = 0.91
# V316 and V318: correlation = 0.94
# V316 and V322: correlation = 1.00
# V316 and V323: correlation = 0.94
# V316 and V324: correlation = 0.93
# V316 and V331: correlation = 0.99
# V316 and V332: correlation = 0.94
# V316 and V333: correlation = 0.93
# V317 and V318: correlation = 0.97
# V317 and V322: correlation = 0.95
# V317 and V323: correlation = 1.00
# V317 and V324: correlation = 0.99
# V317 and V329: correlation = 0.93
# V317 and V331: correlation = 0.94
# V317 and V332: correlation = 1.00
# V317 and V333: correlation = 0.98
# V318 and V322: correlation = 0.94
# V318 and V323: correlation = 0.99
# V318 and V324: correlation = 1.00
# V318 and V329: correlation = 0.95
# V318 and V331: correlation = 0.94
# V318 and V332: correlation = 0.99
# V318 and V333: correlation = 0.99
# V319 and V321: correlation = 0.92
# V320 and V321: correlation = 0.94
# V322 and V323: correlation = 0.94
# V322 and V324: correlation = 0.94
# V322 and V331: correlation = 0.99
# V322 and V332: correlation = 0.94
# V322 and V333: correlation = 0.93
# V323 and V324: correlation = 0.99
# V323 and V329: correlation = 0.95
# V323 and V331: correlation = 0.93
# V323 and V332: correlation = 0.99
# V323 and V333: correlation = 0.99
# V324 and V329: correlation = 0.96
# V324 and V330: correlation = 0.91
# V324 and V331: correlation = 0.92
# V324 and V332: correlation = 0.99
# V324 and V333: correlation = 0.99
# V326 and V327: correlation = 0.94
# V328 and V330: correlation = 0.93
# V329 and V330: correlation = 0.97
# V329 and V332: correlation = 0.94
# V329 and V333: correlation = 0.95
# V331 and V332: correlation = 0.95
# V331 and V333: correlation = 0.94
# V332 and V333: correlation = 0.99
# V334 and V336: correlation = 0.91
# V335 and V336: correlation = 0.91
# V337 and V339: correlation = 0.91
# V338 and V339: correlation = 0.94

# %%
# how many pairs of V columns have correlation >0.99 or <-0.99
v_corr = df[v_cols].corr()
high_corr_99 = v_corr[(v_corr > 0.99) | (v_corr < -0.99)]
high_corr_pairs_99 = []
for i in range(len(high_corr_99.columns)):
    for j in range(i + 1, len(high_corr_99.columns)):
        if not np.isnan(high_corr_99.iloc[i, j]):
            high_corr_pairs_99.append((high_corr_99.columns[i], high_corr_99.columns[j], high_corr_99.iloc[i, j]))
print(f"Number of V column pairs with |correlation| > 0.99: {len(high_corr_pairs_99)}")
# Out:
# Number of V column pairs with |correlation| > 0.99: 139

# %%
# of the >0.99 correlated pairs, choose one column to drop from each pair (the one with more missing values), drop to df_clean
cols_to_drop_corr = set()
for col1, col2, corr_value in high_corr_pairs_99:
    missing_col1 = df[col1].isnull().mean()
    missing_col2 = df[col2].isnull().mean()
    if missing_col1 > missing_col2:
        cols_to_drop_corr.add(col1)
    else:
        cols_to_drop_corr.add(col2)
print(f"Columns to drop due to high correlation: {cols_to_drop_corr}")
df_clean = df_clean.drop(columns=cols_to_drop_corr)
# Out:
# Columns to drop due to high correlation: {'V18', 'V330', 'V316', 'V101', 'V231', 'V317', 'V276', 'V179', 'V103', 'V331', 'V164', 'V329', 'V102', 'V126', 'V95', 'V213', 'V232', 'V269', 'V322', 'V167', 'V211', 'V182', 'V134', 'V97', 'V318', 'V295', 'V233', 'V177', 'V133', 'V323', 'V132', 'V332', 'V296', 'V324', 'V333', 'V293'}

# %%
# histogram distribution of TransactionAmt, 2 graphs by fraud status
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df[df['isFraud'] == 0]['TransactionAmt'], bins=50, kde=True)
plt.title('Transaction Amount Distribution (Not Fraud)')
plt.subplot(1, 2, 2)
sns.histplot(df[df['isFraud'] == 1]['TransactionAmt'], bins=50, kde=True)
plt.title('Transaction Amount Distribution (Fraud)')
plt.show()

# %%
# list counts of TransactionAmt by fraud status, split into categories of integers, round decimals e.g. 10.10, and odd decimals e.g. 10.11
df['TransactionAmt_cat'] = df['TransactionAmt'].apply(lambda x: 'integer' if x.is_integer() else ('round_decimal' if round(x, 2) == round(x, 0) + 0.10 else 'odd_decimal'))
transaction_amt_counts = df.groupby(['isFraud', 'TransactionAmt_cat']).size().unstack(fill_value=0)
print(transaction_amt_counts)

# % of categories by fraud status
transaction_amt_pct = transaction_amt_counts.div(transaction_amt_counts.sum(axis=1), axis=0) * 100
print(transaction_amt_pct)
# Out:
# TransactionAmt_cat  integer  odd_decimal  round_decimal
# isFraud
# 0                    294131       274854            892
# 1                     10882         9707             74
# TransactionAmt_cat    integer  odd_decimal  round_decimal
# isFraud
# 0                   51.613067    48.230408       0.156525
# 1                   52.664182    46.977690       0.358128

# %%
# save df_clean to csv
df_clean.to_csv('data/IEEE-CIS/df_clean.csv', index=False)
